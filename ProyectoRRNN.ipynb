# %% [markdown]
# # 07MIAR - Redes Neuronales y Deep Learning: Proyecto de programación "*Deep Vision in classification tasks*"

# %% [markdown]
# ### Estudiantes:
# - Alfredo Osiglia Rodríguez
# - Laura Elena Betancourt Leal
# - Luis Angel Motta Valero
#
# #### <u>**Importante**</u>: Esta es una copia del notebook original, el cual se ha perdido. Los resultados se muestran en un documento PDF albergado en el siguiente enlace.
#
# **Enlace:** https://drive.google.com/file/d/1Eqw_yPkUVoqsPH1DQ5RNO_HbhVdlsy7a/view?usp=sharing

# %% [markdown]
# ## Descripción previa
# La siguiente información es extraída del repositorio donde se almacena el dataset original (https://www.kaggle.com/datasets/misrakahmed/vegetable-image-dataset).
# ### Nombre: Vegetable Image Dataset
# Clasificación y reconocimiento de vegetales
# ### Contexto
# El experimento inicial se realiza con 15 tipos de hortalizas comunes en todo el mundo. Las verduras elegidas para el experimento son: judía, calabaza amarga, calabaza de botella, berenjena, brécol, col, pimiento, zanahoria, coliflor, pepino, papaya, patata, calabaza, rábano y tomate. Se utiliza un total de **21000** imágenes de 15 clases, cada una de las cuales contiene 1400 imágenes de tamaño $224×224$ y en formato *$.jpg$. El conjunto de datos se divide en un 70% para la formación, un 15% para la validación y un 15% para las pruebas.
#
# ### Contenido
# Este dataset contiene tres folders:
#
# - train (15000 imágenes)
# - test (3000 imágenes)
# - validation (3000 imágenes)
#
# Cada una de las carpetas anteriores contiene subcarpetas para distintos vegetales en las que están presentes las imágenes de los vegetales/hortalizas respectivos.
#
# De acuerdo con lo anterior, las 15 clases son las siguientes:
#
# $Y = ['Bean', 'Bitter Gourd', 'Bottle Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']$

# %% [markdown]
# ## 1.	Carga	del	conjunto	de	datos
#
# En	primer	lugar,	instalamos	la	API	de	Kaggle	y	procedemos	a	descargar	el	fichero	vegetable-image-dataset.zip	que	incluye	todas	las
# imágenes	que	se	utilizarán	para	entrenar	a	la	red.	Este	fichero	se	descomprime	en	la	carpeta	my_dataset.

# %%
# %%capture
# Instalación de la última versión de la API de Kaggle en Colab
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.16.tar.gz (83 kB)
#      -------------------------------------- 83.6/83.6 kB 334.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.16-py3-none-any.whl size=110686 sha256=b3f5428a501bf6a63cda54ccf9098209972a08a55a82d3e90b7cf67616ac33dd
#   Stored in directory: c:\users\user eat\appdata\local\pip\cache\wheels\d2\ed\a5\da3a0cfb13373d1ace41cafa4f2467d858c55c52473ba72799
# Successfully built kaggle
# Installing collected packages: kaggle
# Successfully installed kaggle-1.5.16

# %%
# Seleccionar el API Token personal previamente descargado (fichero kaggle.json)
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import os
os.environ['KAGGLE_USERNAME'] = "angelm97"
os.environ['KAGGLE_KEY'] = "b2d97666b7674148aa715f3cf203f73e"

# %%
#	Descargamos	el	dataset	proveniente	de	Kaggle
# !kaggle datasets download -d misrakahmed/vegetable-image-dataset
# Out:
# Downloading vegetable-image-dataset.zip to /content
# 100% 533M/534M [00:04<00:00, 149MB/s]
# 100% 534M/534M [00:04<00:00, 120MB/s]

# %%
# Creemos un directorio para descomprimir los datos
# !mkdir my_dataset

# %%
# %%capture
# Descomprimimos los datos y los dejamos listos para trabajar
# !unzip vegetable-image-dataset.zip -d my_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: my_dataset/Vegetable Images/train/Radish/0001.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0002.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0003.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0004.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0005.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0006.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0007.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0008.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0009.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0010.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0011.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0012.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0013.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0014.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0015.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0016.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0017.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0018.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0019.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0020.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0021.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0022.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0023.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0024.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0025.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0026.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0027.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0028.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0029.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0030.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0031.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0032.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0033.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0034.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0035.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0036.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0037.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0038.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0039.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0040.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0041.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0042.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0043.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0044.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0045.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0046.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0047.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0048.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0049.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0050.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0051.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0052.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0053.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0054.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0055.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0056.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0057.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0058.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0059.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0060.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0061.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0062.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0063.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0064.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0065.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0066.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0067.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0068.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0069.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0070.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0071.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0072.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0073.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0074.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0075.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0076.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0077.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0078.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0079.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0080.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0081.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0082.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0083.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0084.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0085.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0086.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0087.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0088.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0089.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0090.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0091.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0092.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0093.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0094.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0095.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0096.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0097.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0098.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0099.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0100.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0101.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0102.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0103.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0104.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0105.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0106.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0107.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0108.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0109.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0110.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0111.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0112.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0113.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0114.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0115.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0116.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0117.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0118.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0119.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0120.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0121.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0122.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0123.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0124.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0125.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0126.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0127.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0128.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0129.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0130.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0131.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0132.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0133.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0134.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0135.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0136.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0137.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0138.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0139.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0140.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0141.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0142.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0143.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0144.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0145.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0146.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0147.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0148.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0149.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0150.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0151.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0152.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0153.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0154.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0155.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0156.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0157.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0158.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0159.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0160.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0161.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0162.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0163.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0164.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0165.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0166.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0167.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0168.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0169.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0170.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0171.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0172.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0173.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0174.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0175.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0176.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0177.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0178.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0179.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0180.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0181.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0182.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0183.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0184.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0185.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0186.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0187.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0188.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0189.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0190.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0191.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0192.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0193.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0194.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0195.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0196.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0197.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0198.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0199.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0200.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0201.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0202.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0203.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0204.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0205.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0206.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0207.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0208.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0209.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0210.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0211.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0212.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0213.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0214.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0215.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0216.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0217.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0218.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0219.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0220.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0221.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0222.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0223.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0224.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0225.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0226.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0227.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0228.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0229.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0230.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0231.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0232.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0233.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0234.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0235.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0236.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0237.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0238.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0239.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0240.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0241.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0242.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0243.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0244.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0245.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0246.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0247.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0248.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0249.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0250.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0251.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0252.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0253.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0254.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0255.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0256.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0257.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0258.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0259.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0260.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0261.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0262.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0263.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0264.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0265.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0266.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0267.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0268.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0269.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0270.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0271.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0272.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0273.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0274.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0275.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0276.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0277.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0278.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0279.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0280.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0281.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0282.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0283.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0284.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0285.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0286.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0287.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0288.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0289.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0290.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0291.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0292.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0293.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0294.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0295.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0296.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0297.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0298.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0299.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0300.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0301.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0302.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0303.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0304.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0305.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0306.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0307.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0308.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0309.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0310.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0311.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0312.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0313.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0314.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0315.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0316.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0317.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0318.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0319.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0320.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0321.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0322.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0323.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0324.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0325.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0326.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0327.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0328.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0329.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0330.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0331.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0332.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0333.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0334.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0335.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0336.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0337.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0338.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0339.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0340.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0341.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0342.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0343.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0344.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0345.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0346.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0347.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0348.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0349.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0350.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0351.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0352.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0353.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0354.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0355.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0356.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0357.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0358.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0359.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0360.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0361.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0362.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0363.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0364.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0365.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0366.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0367.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0368.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0369.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0370.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0371.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0372.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0373.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0374.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0375.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0376.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0377.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0378.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0379.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0380.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0381.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0382.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0383.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0384.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0385.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0386.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0387.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0388.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0389.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0390.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0391.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0392.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0393.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0394.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0395.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0396.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0397.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0398.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0399.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0400.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0401.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0402.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0403.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0404.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0405.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0406.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0407.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0408.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0409.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0410.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0411.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0412.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0413.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0414.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0415.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0416.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0417.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0418.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0419.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0420.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0421.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0422.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0423.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0424.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0425.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0426.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0427.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0428.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0429.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0430.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0431.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0432.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0433.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0434.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0435.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0436.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0437.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0438.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0439.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0440.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0441.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0442.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0443.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0444.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0445.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0446.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0447.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0448.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0449.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0450.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0451.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0452.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0453.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0454.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0455.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0456.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0457.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0458.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0459.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0460.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0461.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0462.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0463.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0464.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0465.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0466.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0467.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0468.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0469.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0470.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0471.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0472.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0473.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0474.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0475.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0476.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0477.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0478.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0479.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0480.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0481.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0482.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0483.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0484.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0485.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0486.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0487.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0488.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0489.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0490.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0491.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0492.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0493.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0494.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0495.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0496.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0497.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0498.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0499.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0500.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0501.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0502.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0503.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0504.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0505.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0506.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0507.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0508.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0509.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0510.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0511.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0512.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0513.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0514.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0515.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0516.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0517.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0518.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0519.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0520.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0521.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0522.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0523.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0524.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0525.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0526.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0527.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0528.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0529.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0530.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0531.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0532.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0533.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0534.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0535.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0536.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0537.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0538.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0539.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0540.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0541.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0542.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0543.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0544.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0545.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0546.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0547.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0548.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0549.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0550.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0551.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0552.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0553.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0554.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0555.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0556.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0557.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0558.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0559.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0560.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0561.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0562.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0563.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0564.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0565.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0566.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0567.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0568.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0569.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0570.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0571.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0572.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0573.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0574.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0575.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0576.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0577.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0578.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0579.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0580.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0581.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0582.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0583.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0584.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0585.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0586.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0587.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0588.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0589.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0590.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0591.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0592.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0593.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0594.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0595.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0596.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0597.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0598.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0599.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0600.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0601.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0602.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0603.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0604.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0605.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0606.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0607.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0608.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0609.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0610.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0611.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0612.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0613.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0614.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0615.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0616.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0617.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0618.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0619.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0620.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0621.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0622.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0623.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0624.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0625.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0626.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0627.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0628.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0629.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0630.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0631.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0632.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0633.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0634.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0635.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0636.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0637.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0638.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0639.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0640.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0641.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0642.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0643.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0644.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0645.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0646.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0647.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0648.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0649.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0650.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0651.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0652.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0653.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0654.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0655.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0656.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0657.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0658.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0659.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0660.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0661.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0662.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0663.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0664.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0665.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0666.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0667.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0668.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0669.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0670.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0671.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0672.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0673.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0674.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0675.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0676.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0677.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0678.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0679.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0680.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0681.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0682.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0683.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0684.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0685.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0686.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0687.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0688.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0689.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0690.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0691.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0692.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0693.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0694.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0695.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0696.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0697.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0698.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0699.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0700.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0701.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0702.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0703.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0704.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0705.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0706.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0707.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0708.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0709.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0710.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0711.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0712.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0713.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0714.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0715.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0716.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0717.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0718.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0719.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0720.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0721.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0722.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0723.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0724.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0725.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0726.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0727.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0728.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0729.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0730.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0731.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0732.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0733.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0734.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0735.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0736.jpg
#   inflating: my_dataset/Vegetable Images/train/Radish/0737.jpg
# ...
#   inflating: my_dataset/Vegetable Images/validation/Radish/1373.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1374.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1375.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1376.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1377.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1378.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1379.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1380.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1381.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1382.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1383.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1384.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1385.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1386.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1387.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1388.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1389.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1390.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1391.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1392.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1393.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1394.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1395.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1396.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1397.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1398.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1399.jpg
#   inflating: my_dataset/Vegetable Images/validation/Radish/1400.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1201.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1202.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1203.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1204.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1205.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1206.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1207.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1208.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1209.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1210.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1211.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1212.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1213.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1214.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1215.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1216.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1217.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1218.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1219.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1220.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1221.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1222.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1223.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1224.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1225.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1226.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1227.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1228.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1229.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1230.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1231.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1232.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1233.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1234.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1235.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1236.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1237.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1238.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1239.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1240.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1241.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1242.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1243.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1244.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1245.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1246.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1247.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1248.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1249.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1250.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1251.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1252.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1253.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1254.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1255.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1256.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1257.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1258.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1259.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1260.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1261.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1262.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1263.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1264.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1265.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1266.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1267.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1268.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1269.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1270.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1271.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1272.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1273.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1274.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1275.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1276.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1277.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1278.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1279.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1280.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1281.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1282.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1283.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1284.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1285.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1286.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1287.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1288.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1289.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1290.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1291.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1292.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1293.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1294.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1295.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1296.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1297.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1298.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1299.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1300.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1301.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1302.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1303.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1304.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1305.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1306.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1307.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1308.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1309.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1310.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1311.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1312.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1313.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1314.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1315.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1316.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1317.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1318.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1319.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1320.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1321.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1322.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1323.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1324.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1325.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1326.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1327.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1328.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1329.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1330.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1331.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1332.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1333.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1334.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1335.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1336.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1337.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1338.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1339.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1340.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1341.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1342.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1343.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1344.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1345.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1346.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1347.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1348.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1349.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1350.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1351.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1352.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1353.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1354.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1355.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1356.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1357.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1358.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1359.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1360.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1361.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1362.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1363.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1364.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1365.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1366.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1367.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1368.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1369.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1370.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1371.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1372.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1373.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1374.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1375.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1376.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1377.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1378.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1379.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1380.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1381.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1382.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1383.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1384.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1385.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1386.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1387.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1388.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1389.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1390.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1391.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1392.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1393.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1394.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1395.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1396.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1397.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1398.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1399.jpg
#   inflating: my_dataset/Vegetable Images/validation/Tomato/1400.jpg

# %%
# %%capture
# !ls test/

# %% [markdown]
# ## 2.	Inspección	del	conjunto	de	datos
#
# En	este	apartado	hacemos	una	exploración	inicial	de	los	datos	para	confirmar	que	tienen	la	estructura	adecuada.

# %%
#Verificamos	si	todas	las	imágenes	tienen	el	mismo	tamaño
import	os
from PIL import Image
def	check_image_sizes_recursive(folder_path):
    for	root, dirs, files in os.walk(folder_path):
        for file in	files:
            if	file.lower().endswith('.jpg'):
                file_path = os.path.join(root,	file)
                with Image.open(file_path) as img:
                    width, height = img.size
                    if width != 224 or height != 224:
                        print(f"File: {file_path} - Size: {width}x{height}")

#Mostramos	los	datos	y	ubicación	de	las	imágenes	que	no	cumplen	con	el	tamaño	de	224x224	píxeles
folder_path = './drive/MyDrive/my_dataset'
check_image_sizes_recursive(folder_path)

# %% [markdown]
# Se observa que algunas imágenes de la clase 'Papaya' y otras de la clase 'Bitter_Gourd' tienen un tamaño distinto a 224 x 224. Las imágenes en cuestión son las siguientes:
#
# **Clase 'Bitter_Gourd':**
#
# Train: 3 imágenes.
# - 0526.jpg	-	Size:	224x205
# - 0430.jpg	-	Size:	224x193
# - 0609.jpg	-	Size:	224x200
#
# **Clase 'Papaya':**
#
# Test: 1 imagen.
# - 1246.jpg	-	Size:	224x207
#
# Train: 3 imágenes
# - 0741.jpg	-	Size:	224x210
# - 0126.jpg	-	Size:	224x211
# - 0176.jpg	-	Size:	224x198
#
# Validation: 2 imágenes
# - 1138.jpg	-	Size:	224x187
# - 1150.jpg	-	Size:	224x223
#
# Todas	las	imágenes	tienen	un	width	the	224px	pero	no	todas	tienen	la	misma	altura.	Al	asignar	el atributo	"padding=same"	a	las primeras	capas	convolucionales,	Tensorflow	añadirá	un	padding	de	ceros	(píxeles	de color	negro)	a	estas	imágenes	para	que	cumplan con	la	altura	de	224px	del	resto	de	imágenes.	Esto	no debería	suponer	un	inconveniente	para	la	red	debido	a	que	son	muy	pocas imágenes	a	las	que	se	hará	esta	padding	con	respecto	al	tamaño	del	dataset.
#
# A	continuación,	se	separan	los	datos	en	conjuntos	de	train,	test	y	validation	de	acuerdo	a	como	están estructurados	en	el	fichero	de Kaggle	y	se	hace	visualizan	imágenes	aleatorias	para	confirmar	que	se	han	cargado	de	manera	correcta.

# %%
# Creamos una función para guardar las imágenes en tensores
import tensorflow as tf
from pathlib import Path
path = '/content/my_dataset/Vegetable Images'
#Se	ha	fijado	el	batch_size	que	viene	por	defecto	en	la	documentación
def load_dataset(subfolder,	batch_size=32):
    dataset_path = path + subfolder
    data_dir = Path(dataset_path)
    params = {
        'directory': data_dir,
        'seed':	0,
        'batch_size': batch_size,
        'image_size': (224,224)
        }
    dataset_params = {**params}
    dataset	= tf.keras.utils.image_dataset_from_directory(**dataset_params)
    return dataset

# %%
# Guardamos los diferentes conjuntos de imágenes en variables
print('>> Training Set:')
train_ds = load_dataset('/train')
print('>> Testing Set:')
test_ds = load_dataset('/test',	None)
print('>> Validation Set:')
val_ds = load_dataset('/validation')

# %%
# Definimos las clases
class_names = test_ds.class_names
class_names

# %%
# Visualización de los datos de train
import matplotlib.pyplot as plt

plt.figure(figsize=(14,10))
for images, labels in train_ds.take(1):
    for i in range(21):
        ax = plt.subplot(4, 7, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis('off')

# %% [markdown]
# ## 3.	Acondicionamiento	de	los	datos
#
# Teniendo	ya	las	imágenes	cargadas	en	el	entorno	y	subdivididas	en	conjuntos	de	train,	validation	y test; se	procede	a	normalizar	las imágenes	para	todos	los	conjuntos	y	a	codificar	las	etiquetas	usando	One-Hot Encoding	únicamente	para	el	train	y	validation.

# %%
# Normalización y aplicación de One-hot Encoding

from tensorflow.keras.layers import	Rescaling, CategoryEncoding

# Creación de una capa de re-escalado (normalización de datos)
rescaling_layer = Rescaling(1.0/255)

# Conversión a one-hot encoding
OHE = CategoryEncoding(num_tokens=15, output_mode="one_hot")

# Aplicamos normalización a cada imagen del dataset y OHE a las etiquetas
norm_train = train_ds.map(lambda x,y: (rescaling_layer(x), OHE(y)))
norm_val = val_ds.map(lambda x,y: (rescaling_layer(x), OHE(y)))

# %%
# Separamos el conjunto de test entre imágenes y sus etiquetas
# Se utilizarán para evaluar la precisión del modelo
import numpy as np

x_test = []
y_test = []
norm_test = test_ds.map(lambda x,y: (rescaling_layer(x), y)) # dejamos intactas las etiquetas (y)

for image, label in norm_test.take(len(norm_test)):
    x_test.append(image)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)
print("Test	set	shape:")
print(f'Images:	{x_test.shape}')
print(f'Labels:	{y_test.shape}')

# %% [markdown]
# ## 4.1	Desarrollo	y	entrenamiento	de	un	modelo	desde	cero	o from	scratch
#
# En	este	apartado	se	procede	a	entrenar	un	modelo	"from	scratch"	definiendo	la	arquitectura	desde cero, observando	cómo	se	comporta en	el	entrenamiento	y	aplicando	técnicas	de	regularización	para	mejorar	su rendimiento.	Partimos	de	una	arquitectura	con	tres	bloques convolucionales	sobre	los	que	únicamente	se	aplica	max pooling	antes	de	pasar	al	siguiente	bloque	y	una	capa	MLP	sin	ningún	tipo	de regularización.	Luego aplicamos las	técnicas	de	batch	normalization	y	dropout	para	observar	cómo	cambia	el	accuracy.	En	el	tercer modelo	se	aplicará	la	técnica	de	Early	Stopping.	Finalmente,	aplicamos	la	técnica	de	Data	Augmentation para intentar	reducir	aún	más	el overfitting.

# %% [markdown]
# ## 4.1.1	Modelo	from	scratch	únicamente	con	max	pooling
#
# ### Definición del modelo

# %%
# Importamos las librerías necesarias
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 

#########################################
###### Definimos la arquitectura ########
#########################################
#BASE MODEL
# Definimos entradas
inputs = Input(shape=(224, 224, 3))

# Primer set de capas CONV
x1 = Conv2D(32, (3,	3),	padding="same",	activation="relu")(inputs)
x1 = Conv2D(32, (3,	3),	padding="same",	activation="relu")(x1)
x1 = MaxPooling2D(pool_size=(2,	2))(x1)
x1 = Dropout(0.25)(x1)

# Segundo set de capas CONV
x2 = Conv2D(64,	(3,	3),	padding="same",	activation="relu")(x1)	#(X)
x2 = Conv2D(64,	(3,	3),	padding="same",	activation="relu")(x2)	#(X)
x2 = MaxPooling2D(pool_size=(2,	2))(x2)	#(X)

#	Tercer	set	de	capas	CONV
x3 = Conv2D(256,	(3,	3),	padding="same",	activation="relu")(x2)	#(X)
x3 = Conv2D(256,	(3,	3),	padding="same",	activation="relu")(x3)	#(X)
x3 = MaxPooling2D(pool_size=(2,	2))(x3)	#(X)

# TOP MODEL
# Primer (y único) set de capas FC => RELU
xfc = Flatten()(x3)	#(X)
xfc = Dense(512,	activation="relu")(xfc)
predictions = Dense(15,	activation="softmax")(xfc)	#(X)

# %% [markdown]
# ### Compilación	del	modelo

# %%
# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y outputs
model_cnn = Model(inputs=inputs, outputs=predictions)	#(X)
# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_cnn.compile(loss="categorical_crossentropy",
                  optimizer=Adam(learning_rate=0.001,	beta_1=0.9,	beta_2=0.999,	epsilon=1e-08),
                  metrics=["accuracy"])	#(X)

n_epochs=20

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
# IMPORTANTE (Consultar la documentación)
H = model_cnn.fit(norm_train, validation_data=norm_val, batch_size=128, epochs=n_epochs, verbose=1)	#(X)

# %% [markdown]
# ### Evaluación	del	modelo
#
# Como	era	de	esperar,	el	modelo	presenta	una	cantidad	importante	de	overfitting	debido	a	que	no	se	ha aplicado	ninguna	técnica	de regularización	más	allá	del	max	pooling.	Se	observa	que	en	la	última	época	el	modelo no	solo	no	mejora	si	no	que	parece	tener tendencia	a	divergir.

# %%
from sklearn.metrics import classification_report

#	Muestro	gráfica	de	accuracy	y	losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H.history["loss"],	label="train_loss")
plt.plot(np.arange(0, 20), H.history["val_loss"],	label="val_loss")
plt.plot(np.arange(0, 20), H.history["accuracy"],	label="train_acc")
plt.plot(np.arange(0, 20), H.history["val_accuracy"],	label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()

# %%
# Evaluación del modelo
print("[INFO]: Evaluando el modelo de red neuronal...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_cnn.predict(x_test,	batch_size=128)	#(X)
# Sacamos el report para test
print(classification_report(y_test,	predictions.argmax(axis=1),	target_names=class_names))	#(X)

# %% [markdown]
# ## 4.1.2	Modelo	from	scratch	aplicando	max	pooling,	batch normalization	y	droput
#
# ### Definición	del	modelo

# %%
# Importamos las librerías necesarias
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Conv2D, Activation, Flatten, Dense, Dropout, BatchNormalization, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 

n_epochs=50
#########################################
###### Definimos la arquitectura ########
#########################################
#BASE MODEL
# Definimos entradas
inputs = Input(shape=(224, 224, 3))

# Primer set de capas CONV => RELU => CONV => RELU => POOL
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
x1 = BatchNormalization()(x1)
x1 = Conv2D(32, (3, 3), padding="same", activation="relu")(x1)
x1 = BatchNormalization()(x1)
x1 = MaxPooling2D(pool_size=(2, 2))(x1)
x1 = Dropout(0.25)(x1)

# Segundo set de capas CONV => RELU => CONV => RELU => POOL
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x1) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = Conv2D(64, (3, 3), padding="same", activation="relu")(x2) #(X)
x2 = BatchNormalization()(x2) #(X)
x2 = MaxPooling2D(pool_size=(2, 2))(x2) #(X)
x2 = Dropout(0.25)(x2) #(X)

# Tercer set de capas CONV => RELU => CONV => RELU => POOL
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x2) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = Conv2D(256, (3, 3), padding="same", activation="relu")(x3) #(X)
x3 = BatchNormalization()(x3) #(X)
x3 = MaxPooling2D(pool_size=(2, 2))(x3) #(X)
x3 = Dropout(0.25)(x3) #(X)

# TOP MODEL
# Primer (y único) set de capas FC => RELU
xfc = Flatten()(x3) #(X)
xfc = Dense(512, activation="relu")(xfc) #(X)
xfc = BatchNormalization()(xfc) #(X)
xfc = Dropout(0.5)(xfc) #(X)
# Clasificador softmax
predictions = Dense(15, activation="softmax")(xfc) #(X)

# %% [markdown]
# ### Compilación	del	modelo

# %%
# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y ouputs
model_cnn = Model(inputs=inputs, outputs=predictions) #(X)

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_cnn.compile(loss="categorical_crossentropy",
#                 loss='sparse_categorical_crossentropy',
                  optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08),
                  metrics=["accuracy"]) #(X)

n_epochs=20

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
# IMPORTANTE (Consultar la documentación)
H = model_cnn.fit(norm_train, validation_data=norm_val, batch_size=128, epochs=n_epochs, verbose=1)	#(X)

# %% [markdown]
# ### Evaluación	del	modelo
#
# Aquí	se	puede	apreciar	una	mejora	considerable	del	overfitting	visto	en	el	modelo	anterior,	donde	en	la última	epoch	la	diferencia	entre validation	loss	y	training	loss	es	menor	a	0.1.	Es	interesante destacar	el	pico	validation	loss	en	la	epoch,	que	puede	ser	causa	de diversos	factores,	como sensibilidad del	modelo	durante	la	inicialización	o	una	variabilidad	marcada	en	el	batch	de	validación	para	esa epoch.
#
# En	este	modelo	se	ha	alcanzado	un	f1-score	perfecto	para	la	detección	de	capsicum	(pimiento).	En	el modelo	anterior	el	valor	de	este vegetal	también	fue	el	más	alto	con	un	valor	de	0.97.

# %%
# Muestro gráfica de accuracy y losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, n_epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, n_epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, n_epochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, n_epochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

# Evaluación del modelo
print("[INFO]: Evaluando el modelo de red neuronal...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_cnn.predict(x_test, batch_size=128) #(X)
# Sacamos el report para test
print(classification_report(y_test, predictions.argmax(axis=1), target_names=class_names)) #(X)

# %% [markdown]
# ## 4.1.3	Modelo	from	scratch	aplicando	Early	Stopping
# ### Definición	de	callbacks	para	Early	Stopping	y	compilación
#
# Hasta	ahora	se	ha	realizado	el	entrenamiento	de	la	red	con	un	número	de	epochs	igual	a	20.	Ahora	se aplica	un	Early	Stopping	con patience=3	y	se	espera	tener	un	número	de	epochs	distinto	al	finalizar	el	entrenamiento

# %%
#	Unimos	las	entradas	y	el	modelo	mediante	la	función	Model	con	parámetros	inputs	y	ouputs	(Consultar	la	documentació
model_cnn	=	Model(inputs=inputs,	outputs=predictions)	#(X)
#	Compilar	el	modelo
print("[INFO]:	Compilando	el	modelo...")
model_cnn.compile(loss="categorical_crossentropy",
#                 loss='sparse_categorical_crossentropy',
                  optimizer=Adam(learning_rate=0.001,	beta_1=0.9,	beta_2=0.999,	epsilon=1e-08),
                  metrics=["accuracy"])	#(X)
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                     patience=3,	# Valor de patience con mejor resultado entre 2-5
                                     mode='min'),
    tf.keras.callbacks.ModelCheckpoint(filepath='/content/',
                                       monitor='val_accuracy',
                                       save_weights_only=True,
                                       mode='max'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

n_epochs=50

# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
# IMPORTANTE (Consultar la documentación)
H = model_cnn.fit(norm_train, validation_data=norm_val, batch_size=128, epochs=n_epochs, verbose=1, callbacks=my_callbacks)

# %% [markdown]
# ### Evaluación	del	modelo
#
# El	modelo	se	detiene	en	la	época	9.	Aunque	no	hay	mejora	en	el	overfitting	con	respecto	al	modelo	anterior, el	tiempo	de	entrenamiento se	ha	reducido	a	la	mitad.	Los	resultados	de	test	son	parecidos	a	los	obtenidos	en	el	modelo	4.1.1.

# %%
#	Muestro	gráfica	de	accuracy	y	losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 9), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 9), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 9), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 9), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
# Evaluación del modelo
print("[INFO]: Evaluando el modelo de red neuronal...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_cnn.predict(x_test, batch_size=128)	#(X)
# Sacamos el report para test
print(classification_report(y_test,	predictions.argmax(axis=1), target_names=class_names))	#(X)

# %% [markdown]
# ## 4.1.4	Modelo	from	scratch	aplicando	Data	Augmentation
#
# ### Generación	de	contenedor	DataGenerator	para	el	aumento	automático	de muestras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=12,	    # grados de rotacion aleatoria
    width_shift_range=0.2,	# fraccion del total (1) para mover la imagen
    height_shift_range=0.2,	# fraccion del total (1) para mover la imagen
    horizontal_flip=True,	# girar las imagenes horizontalmente (eje vertical)
    #	shear_range=0,	#	deslizamiento
    zoom_range=0.2,	# rango de zoom
    #	fill_mode='nearest',	#	como	rellenar	posibles	nuevos	pixeles
    #	channel_shift_range=0.2	#	cambios	aleatorios	en	los	canales	de	la	imagen
)

# %%
# Carga del conjunto de test
# Los datos de train y validation se cargan durante el entrenamiento del modelo
import numpy as np
test_aug = load_dataset('/test',	None)
x_test_aug = []
y_test_aug = []
# norm_test = test_aug.map(lambda x,y: (rescaling_layer(x),	y))
for image, label in test_aug.take(len(test_aug)):
    x_test_aug.append(image)
    y_test_aug.append(label)
x_test_aug = np.array(x_test_aug)
y_test_aug = np.array(y_test_aug)
# Guardamos las clases en una variable
class_names_aug = test_aug.class_names

# %% [markdown]
# ### Inspección	de	muestras	generadas	sintéticamente

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.backend import expand_dims
import matplotlib.pyplot as plt
# %matplotlib	inline

# Tomamos uno de los ejemplos de imágenes de train
for images, labels in train_ds.take(1):
    sample = np.random.randint(len(images))
    sample_train_x = images[sample]
    sample_class = class_names_aug[labels[sample]]
plt.imshow(sample_train_x.numpy().astype('uint8'))
plt.title(sample_class)
plt.axis('off')
plt.show()

# Visualizamos las transformaciones hechas por la técnica de Data Augmentation
fig, axes = plt.subplots(2,2)
i = 0
for batch in datagen.flow(expand_dims(sample_train_x,	axis=0),batch_size=1):
    #plt.figure(i)
    axes[i//2,i%2].imshow(image.array_to_img(batch[0]))
    i += 1
    if i == 4:
        break
plt.show()

# %% [markdown]
# ### Definición	del	modelo

# %%
# Unimos las entradas y el modelo mediante la función Model con parámetros inputs y ouputs
model_aug =	Model(inputs=inputs, outputs=predictions)	#(X)
# Compilar el modelo
print("[INFO]: Compilando el modelo...")
model_aug.compile(loss="categorical_crossentropy",
#                 loss='sparse_categorical_crossentropy',
                  optimizer=Adam(learning_rate=0.001,	beta_1=0.9,	beta_2=0.999,	epsilon=1e-08),
                  metrics=["accuracy"])	#(X)
callbacks_aug	=	[
    tf.keras.callbacks.ModelCheckpoint(filepath='/content/data_aug',
                                       monitor='val_loss',
                                       save_best_only=True,
                                       mode='min'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

num_epoch=20

#	Entrenamiento	de	la	red
print("[INFO]: Entrenando la red...")
#	IMPORTANTE	(Consultar	la	documentación)
H_aug = model_aug.fit(datagen.flow_from_directory(path + '/train',
                                                  target_size=(224,	224),
                                                  color_mode='rgb',
                                                  classes=class_names_aug,
                                                  class_mode='categorical',
                                                  batch_size=32,
                                                  shuffle=True,
                                                  seed=0),
                       # steps_per_epoch = len(norm_train)/128,
                       validation_data=datagen.flow_from_directory(path	+	'/validation',
                                                                   target_size=(224,	224),
                                                                   color_mode='rgb',
                                                                   classes=class_names_aug,
                                                                   class_mode='categorical',
                                                                   batch_size=32,
                                                                   shuffle=True,
                                                                   seed=0),
                       epochs=num_epoch, verbose=1, callbacks=callbacks_aug)

# %% [markdown]
# ### Evaluación	del	modelo
#
# En	este	modelo	se	han	obtenido	valores	de	f1-score	perfectos	para	la	clasificación	de	patata	y calabaza	amarga	y	casi	perfecta	para	el pimiento,	la	zanahoria	y	el	pepino.	Sin	embargo,	la	clasificación	de otros	vegetales	como	la	calabaza	o	el	coliflor	se	ha	visto	impactada negativamente.	Esto	puede deberse	a	que	las	imágenes	generadas	durante	el	proceso	de	Data	Augmentation	han	tenido	poca representación de	estos	vegetales.
#
# Destacamos	neuvamente	el	pico	de	validation	loss	en	la	época	ocho.	El	hecho	de	que	el	pico	se	repita en	la	misma	época	puede deberse	a	que	el	bache	de	validación	(que	no	cambia	entre	modelos)	contiene imágenes	especialmente	complicadas	de	detectar	para	la red.

# %%
# Gráfica de accuracy y losses
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, num_epoch), H_aug.history["loss"], label="train_loss")
plt.plot(np.arange(0, num_epoch), H_aug.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, num_epoch), H_aug.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, num_epoch), H_aug.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
# Evaluación del modelo
print("[INFO]: Evaluando el modelo de red neuronal...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions = model_aug.predict(x_test_aug,	batch_size=128)	#(X)
# Sacamos el report para test
print(classification_report(y_test_aug,	predictions.argmax(axis=1),	target_names=class_names_aug))

# %% [markdown]
# En	caso	de	que	se	requiera	utilizar	el	modelo	recién	entrenado	(con	el	cual	se	aplicó	Data	augmentation),	se	ha	guardado	en	la	siguiente ruta.

# %%
# Guardamos el modelo si así lo deseamos
model_aug.save('/content/model_aug.h5')

# %% [markdown]
# Luego de subirlo al entorno	de	colab,	se	puede	volver	a	cargar	el	modelo	y	seguir	entrenándolo	si	es	necesario.
#
# Enlace	del	archivo	contenedor:	Modelo	entrenado	aplicando	Data	Augmentation

# %%
from tensorflow.keras.models import load_model
new_model_aug = load_model('/content/model_aug.h5')	#	debe	verificar	la	ruta

#	Verifique	que	el	estado	esté	preservado
#	new_predictions	=	new_model_aug.predict(x_test_aug)
#	np.testing.assert_allclose(predictions,	new_predictions,	rtol=1e-6,	atol=1e-6)

# %% [markdown]
# ## 4.2	Desarrollo	y	entrenamiento	de	un	modelo	a	partir	de redes	preentrenada
#
# A	continuación	se	hace	uso	de	dos	redes	preentrenados	de	ImageNet	para	aplicar	el	concepto	de Transfer Learning	y,	posteriormente, el	de	Fine	Tuning	para	mejorar	el	overfitting.	Las	redes	a	utilizar	serán	la	`VGG16`	y	la	`ResNet50`.

# %% [markdown]
# ## 4.2.1	Modelo	a	partir	de	la	red	VGG16
# ### Preprocesamiento	de	imágenes	de	acuerdo	a	la	red	VGG16
#
# En	primer	lugar,	se	normaliza	el	set	de	datos	de	la	misma	forma	en	la	que	los	creadores	de	la	red	lo hicieron	para	su	entrenamiento.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
from google.colab import drive
from tensorflow.keras.layers import CategoryEncoding
from tensorflow.keras.applications import VGG16, imagenet_utils

# Conversión a one-hot	encoding
OHE = CategoryEncoding(num_tokens=15, output_mode="one_hot")

# Aplicamos one-hot encoding a las etiquetas
norm_train = train_ds.map(lambda x, y: (imagenet_utils.preprocess_input(x), OHE(y)))
norm_val = val_ds.map(lambda x, y: (imagenet_utils.preprocess_input(x), OHE(y)))

# Separamos el conjunto de test entre imágenes y sus etiquetas
# Se utilizarán para evaluar la precisión del modelo
x_test	=	[]
y_test	=	[]
norm_test	=	test_ds.map(lambda	x,y:	(imagenet_utils.preprocess_input(x),	y))	# dejamos intactas las etiquetas (y)
for image, label in norm_test.take(len(norm_test)):
    x_test.append(image)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# ### Carga	del	base	model
#
# Primero usaremos el modelo `VGG16` y análizaremos sus resultados
#
# Al	cargar	el	modelo	se	asigna	el	parámetro	include_top=False,	ya	que	solo	nos	interesa	hacer	uso	del	base model	de	la	red.

# %%
#	Seleccionar	modelo	preentrenado	(VGG16	en	este	caso)

base_model = VGG16(weights='imagenet',
                 include_top=False, # No incluir el top model, i.e. la parte densa destinada a la clasificación (fully connected layers)
                 input_shape=(224,224,3))

# %%
base_model.summary()

# %% [markdown]
# ### Definición	del	top	model	para	Transfer	Learning
#
# Añadimos	de	manera	secuencial	un	MLP	de	256	neuronas	en	la	capa	oculta.

# %%
# conectarlo a nueva parte densa
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

base_model.trainable = False # Evitar que los pesos se modifiquen en la parte convolucional -> TRANSFER LEARNING
pre_trained_model = Sequential()
pre_trained_model.add(base_model)
pre_trained_model.add(layers.Flatten())
pre_trained_model.add(layers.Dense(256, activation='relu'))
pre_trained_model.add(layers.Dense(10, activation='softmax'))

pre_trained_model.summary()

# %% [markdown]
# ### Compilación	del	modelo

# %%
# Import the necessary packages
import numpy as np
from tensorflow.keras import backend	as	K
from tensorflow.keras.layers import	Input,	Conv2D,	Activation,	Flatten,	Dense,	Dropout,	BatchNormalization,	MaxPoolin
from tensorflow.keras.models import	Model
from tensorflow.keras.models import	Sequential
from tensorflow.keras.optimizers import	SGD,	Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Compilar el modelo
print("[INFO]: Compilando el modelo...")
pre_trained_model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.0005, weight_decay=0, beta_1=0.9, beta_2=0.999, epsilon=1e-08))	
# Entrenamiento de la red
print("[INFO]: Entrenando la red...")
H_pre = pre_trained_model.fit(norm_train, batch_size=128, epochs=20, validation_data=norm_val)

# %% [markdown]
# ### Evaluación	del	modelo	de	Transfer	Learning
#
# El	modelo	da	resultados	excelentes	en	el	test.	Esto	es	sorprendente	teniendo	en	cuenta	la	simplicidad	del top	model	que	se	ha	añadido y	es	muestra	de	la	buena	calidad	del	base	model,	cuyas	capas	convolucionales contienen	pesos	entrenados	con	una	cantidad	inmensa de	datos	y	son	excelentes	detectando	características	base como	bordes	y	texturas.	Tenemos	unos	valores	f1-score	perfectos	para	la detección	de	repollo, pimiento zanahoria,	calabaza	y	rábano.	Esto	ya	supera	con	creces	los	resultados	obtenidos	en	la	red	from	scratch, teniendo	todos	los	f1-score	mayores	o	iguales	a	0.99.
#
# El	modelo	entra	en	un	mínimo	local	al	no	observar	mejora	de	la	pérdida	tras	completar	la	mitad	del proceso	del	entrenamiento.	Se buscará	salir	de	este	mínimo	local	aplicando	Fine	Tuning.

# %%
# clases
class_names = test_ds.class_names
class_names

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions	=	pre_trained_model.predict(x_test,	batch_size=128)
#	Sacamos	el	report	para	test
print(classification_report(y_test,	predictions.argmax(axis=1),	target_names=class_names))

#	Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H_pre.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H_pre.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H_pre.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H_pre.history["val_accuracy"], label="val_acc")
plt.title("Training	Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Aplicación	de	Fine	Tuning	y	EarlyStopping	para	reducir	overfitting
#
# El	base	model	se	congela	hasta	una	capa	específica	('block4_pool')	para	evitar	ajustes	innecesarios. Adicionalmente	se	aplica	un	Early Stopping	con	patience=3.

# %%
# Imports	que	vamos	a	necesitar
from tensorflow.keras.applications import VGG16, imagenet_utils
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dropout, Flatten, Dense
from tensorflow.keras import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as	np

#######	BASE	MODEL	######################
# Importamos VGG16 con pesos de imagenet y sin top_model especificando tamaño de entrada de datos
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

#	Mostramos	la	arquitectura
base_model.summary()

# %%
# %%capture
# congelar capas
for layer in base_model.layers:
	if layer.name == 'block4_pool':
		break
	layer.trainable = False
	print('Capa	' + layer.name + ' congelada...')

# Cogemos la última capa del model y le añadimos nuestro clasificador (top_model)
last = base_model.layers[-1].output	#	ultima	capa	del	base	model
x = Flatten()(last)
x = Dense(1024,	activation='relu',	name='fc1')(x)
x = Dropout(0.3)(x)
x = Dense(256,	activation='relu',	name='fc2')(x)
x = Dense(15,	activation='softmax',	name='predictions')(x)
model = Model(base_model.input,	x)

# Compilamos el modelo
model.compile(optimizer=Adam(learning_rate=0.0005,	
							 weight_decay=0,	
							 beta_1=0.9,	
							 beta_2=0.999,	
							 epsilon=1e-08),	
			  loss="categorical_crossentropy")
model.summary()

my_callbacks = [
	tf.keras.callbacks.EarlyStopping(monitor='val_loss',
									 patience=3,	#	Valor	de	patience	con	mejor	resultado	entre	2-5
									 mode='min'),
	tf.keras.callbacks.ModelCheckpoint(filepath='/content/',
									   monitor='val_accuracy',
									   save_weights_only=True,
									   mode='max'),
	tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

n_epochs = 20

# Entrenamos el modelo
H = model.fit(norm_train, validation_data=norm_val, batch_size=128,
			  epochs=n_epochs, verbose=1, callbacks=my_callbacks)

# %% [markdown]
# ## Evaluación	del	modelo	tras	el	Fine	Tuning
#
# Aunque	el	overfitting	haya	mejorado,	se	observa	que	el	accuracy	en	la	etapa	de	test	pasa	de	0.99	a 0.94	al	aplicar	Fine	Tuning.	Esto puede	deberse	a	que	el	hecho	de	reentrenar	el	último	bloque	convolucional redujo	su	capacidad	de	generalización,	quizás	por	la	relativa pequeña	cantidad	de	imágenes	usadas	para entrenar	o	porque	las	imágenes	usadas	para	entrenar	al	VGG16	hayan	sido	muy	distintas	a las	usadas	en	estos	entrenamientos.

# %%
# clases
class_names = test_ds.class_names
class_names

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
predictions = model.predict(x_test,	batch_size=128)
# Obtener el report de clasificación
print(classification_report(y_test,	predictions.argmax(axis=1),	target_names=class_names))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 20), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 20), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 20), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 20), H.history["val_accuracy"], label="val_acc")
plt.title("Training	Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## 4.2.	Modelo	a	partir	de	la	red	ResNet50
#
# Se	empleará	adicionalmente,	la	arquitectura	pre-entrenada	 `ResNet50`,	ya	que	al	igual	que	VGG16,	de	acuerdo	con la	documentación, el	input	shape	tiene	que	ser	 `(224,224,3)`,	siendo	justamente	la	dimensión	que	tiene	las	imágenes	de	nuestro	dataset.

# %% [markdown]
# ### Preprocesamiento	de	imágenes	de	acuerdo	a	la	red	ResNet50

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
from tensorflow.keras.layers import CategoryEncoding
from tensorflow.keras.applications import ResNet50, imagenet_utils

# Conversión a one-hot encoding
OHE = CategoryEncoding(num_tokens=15, output_mode="one_hot")

# Aplicamos one-hot	encoding a las etiquetas
norm_train = train_ds.map(lambda x, y: (imagenet_utils.preprocess_input(x),	OHE(y)))
norm_val = val_ds.map(lambda x, y: (imagenet_utils.preprocess_input(x),	OHE(y)))

# Separamos el conjunto de test entre imágenes y sus etiquetas
# Se utilizarán para evaluar la precisión del modelo
import numpy as np
x_test = []
y_test = []
norm_test = test_ds.map(lambda x,y: (imagenet_utils.preprocess_input(x), y)) # dejamos intactas las etiquetas (y)
for	image, label in norm_test.take(len(norm_test)):
    x_test.append(image)
    y_test.append(label)

x_test	=	np.array(x_test)
y_test	=	np.array(y_test)

# %% [markdown]
# ### Carga del base model

# %%
# %%capture
# Seleccionar	modelo	preentrenado	(ResNet50	en	este	caso)
base_model	=	ResNet50(weights='imagenet',	include_top=False,	input_shape=(224,	224,	3))

base_model.summary()

# %% [markdown]
# ### Definición	del	top	model	para	Transfer	Learning

# %%
#	conectarlo	a	nueva	parte	densa
from	tensorflow.keras.models	import	Sequential
from	tensorflow.keras	import	layers

base_model.trainable	=	False	#	Evitar	que	los	pesos	se	modifiquen	en	la	parte	convolucional	->	TRANSFER	LEARNING
pre_trained_model	=	Sequential()
pre_trained_model.add(base_model)
pre_trained_model.add(layers.Flatten())
pre_trained_model.add(layers.Dense(256,	activation='relu'))
pre_trained_model.add(layers.Dense(15,	activation='softmax'))

pre_trained_model.summary()

# %% [markdown]
# ### Compilación	del	modelo	aplicando	Early	Stopping

# %%
#	Import	the	necessary	packages
import	numpy	as	np
from	tensorflow.keras	import	backend	as	K
from	tensorflow.keras.layers	import	Input,	Conv2D,	Activation,	Flatten,	Dense,	Dropout,	BatchNormalization,	MaxPoolin
from	tensorflow.keras.models	import	Model
from	tensorflow.keras.models	import	Sequential
from	tensorflow.keras.optimizers	import	SGD,	Adam
from	sklearn.metrics	import	classification_report
import	matplotlib.pyplot	as	plt

#	Compilar	el	modelo
print("[INFO]:	Compilando	el	modelo...")
pre_trained_model.compile(loss="categorical_crossentropy",	
                          optimizer=Adam(learning_rate=0.0005,
                                         weight_decay=0,
                                         beta_1=0.9,
                                         beta_2=0.999,
                                         epsilon=1e-08))

#	Entrenamiento	de	la	red
my_callbacks	=	[
				tf.keras.callbacks.EarlyStopping(monitor='val_loss',	#Después	de	algunas	épocas	el	modelo	no	mejora
												 patience=3,
												 mode='min'),
				tf.keras.callbacks.TensorBoard(log_dir='./logs')
]

print("[INFO]:	Entrenando	la	red...")
H_pre	=	pre_trained_model.fit(norm_train,	batch_size=128,	epochs=20,	validation_data=norm_val,	callbacks=my_callbacks)

# %% [markdown]
# ### Evaluación	del	modelo	de	Transfer	Learning
#
# Los	resultados	de	este	modelo	son	muy	similares	a	los	obtenidos	con	el	Transfer	Learning	del	VGG16	y	con menor	overfitting.	Tiene	f1score	perfecto	para	seis	vegetales	(brócoli,	pimiento,	zanahora,patata, rábano	y	tomate).

# %%
#	clases
class_names	=	test_ds.class_names
class_names

# Evaluación del modelo
print("[INFO]: Evaluando el modelo...")
# Efectuamos la predicción (empleamos el mismo valor de batch_size que en training)
predictions	= pre_trained_model.predict(x_test,	batch_size=128)
# Sacamos el report para test
print(classification_report(y_test,	predictions.argmax(axis=1),	target_names=class_names))

# Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 6), H_pre.history["loss"], label="train_loss")
plt.plot(np.arange(0, 6), H_pre.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 6), H_pre.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 6), H_pre.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ### Aplicación	de	Fine	Tuning	y	dropout	para	reducir	overfitting
#
# En	esta	etapa	de	Fine	Tuning	se	congela	el	modelo	hasta	la	capa	conv4_block6_out	y	se	redefine	el	top	model	para	añadir	una	capa
# oculta	adicional	de	1024	neuronas	con	un	dropout	del	30%.

# %%
# %%capture
#	Imports	que	vamos	a	necesitar
from	tensorflow.keras.applications	import	ResNet50,	imagenet_utils
from	tensorflow.keras.utils	import	to_categorical
from	tensorflow.keras	import	optimizers
from	tensorflow.keras.layers	import	Dropout,	Flatten,	Dense
from	tensorflow.keras	import	Model
import	matplotlib.pyplot	as	plt
from	sklearn.metrics	import	classification_report
import	numpy	as	np

#######	BASE	MODEL	######################
#	Cargamos	ResNet50	con	pesos	de	imagenet	y	sin	top_model	especificando	tamaño	de	entrada	de	datos
base_model	=	ResNet50(weights='imagenet',	include_top=False,	input_shape=(224,	224,	3))

# Mostramos	la	arquitectura
base_model.summary()

# %%
for	layer	in	base_model.layers:
		if	layer.name	==	'conv4_block6_out':
				break
		layer.trainable	=	False
		print('Capa	'	+	layer.name	+	'	congelada...')

#	Cogemos	la	última	capa	del	model	y	le	añadimos	nuestro	clasificador	(top_model)
last	=	base_model.layers[-1].output	#	ultima	capa	del	base	model
x	=	Flatten()(last)
x	=	Dense(1024,	activation='relu',	name='fc1')(x)
x	=	Dropout(0.3)(x)
x	=	Dense(256,	activation='relu',	name='fc2')(x)
x	=	Dense(15,	activation='softmax',	name='predictions')(x)
model	=	Model(base_model.input,	x)

#	Compilamos	el	modelo
model.compile(optimizer=Adam(learning_rate=0.0005,	
							 weight_decay=0,	
							 beta_1=0.9,	
							 beta_2=0.999,	
							 epsilon=1e-08),	
			  loss="categorical_crossentropy")
model.summary()

#	Entrenamos	el	modelo
H = model.fit(norm_train, validation_data=norm_val, batch_size=128, epochs=20, verbose=1)

# %% [markdown]
# ### Evaluación	del	modelo	tras	el	Fine	Tuning
#
# Este	es,	con	diferencia	el	mejor	modelo	generado	en	este	proyecto,	con	valores	f1-score	perfectos	para todos	los	vegetales,	aunque presenta	picos	de	validation	loss.

# %%
#	clases
class_names	=	test_ds.class_names
class_names

#	Evaluación	del	modelo
print("[INFO]:	Evaluando	el	modelo...")
predictions	=	model.predict(x_test,	batch_size=128)
#	Obtener	el	report	de	clasificación
print(classification_report(y_test,	predictions.argmax(axis=1),	target_names=class_names))

#	Gráficas
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0,	20),	H.history["loss"],	label="train_loss")
plt.plot(np.arange(0,	20),	H.history["val_loss"],	label="val_loss")
plt.plot(np.arange(0,	20),	H.history["accuracy"],	label="train_acc")
plt.plot(np.arange(0,	20),	H.history["val_accuracy"],	label="val_acc")
plt.title("Training	Loss	and	Accuracy")
plt.xlabel("Epoch	#")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## 5.	Conclusiones
#
# En	este	proyecto	se	ha	generado	una	serie	de	modelos	de	redes	neuronales	convolucionales	utilizando distintas	técnicas	de regularización	para	la	clasificación	de	imágenes	de	quince	variedades	de	vegetales.
#
# Los	modelos	construidos	desde	cero	mostraron	tendencia	al	overfitting	con	mejoras	notables	al	introducir	las técnicas	de	batch normalization	y	dropout.	Las	técnicas	de	Early	Stopping	no	mejoró	el	rendimiento	tanto como	se	esperaba	pero	esto	puede	deberse	a	los movimientos	erráticos	en	el	validation	loss	que	se	han observado	en	la	mayoría	de	los	modelos,	lo	que	puede	suponer	que	introducir	una interrupción	temprana	al proceso	de	entrenamiento	no	permita	a	la	red	recomponerse	correctamente	de	estos	picos	de	pérdida	para lograr converger	satisfactoriamente.	En	cuanto	a	la	técnica	de	Data	Augmentation,	aunque	mejoró	la	clasificación para algunos vegetales,	empeoró	el	accuracy	general	en	la	fase	test.	El	riesgo	de	utilizar	Data	Augmentation es que	puede	resultar	en	overfitting	para los	datos	generados	de	manera	sintéticamente,	lo	que	podría	haber afectado	a	los	vegetales	poco	representados	durante	la	generación.
#
# Los	modelos	entrenados	mediante	Transfer	Learning	han	dado	resultados	superiores	a	los	del	modelo	construido desde	cero.	El	modelo basado	en	ResNet50	se	destacó	como	el	más	exitoso,	obteniendo	una	precisión perfecta para	todas	las	variedades	de	vegetales.	Esto tiene	sentido	al	ser	este	un	modelo	mucho	más	complejo	y profundoo en	cuanto	a	arquitectura	respecto	al	VGG16.	ResNet50	está compuesto	de	50	capas	convolucionales	y	el VGG16	tiene	16.	Por	esta	razón	se	presume,	que	el	ResNet50	ha	respondido	mucho	mejor al	Fine	Tuning, al	tener	las	capas	que	detectan	características	básicas	más	alejadas	de	las	capas	especializadas	se	pueden reentrenar las	últimas	capas	de	manera	que	estas	se	adapten	mucho	mejor	a	los	nuevos	datos	de	entrenamiento.	 En	el	caso	de	VGG16,	entrenar el	último	bloque	convolucional	supondría	sobreescribir	los	pesos que,	al	contar	con	poca	profundidad	en	la	red,	aún	son	muy	importantes para	extraer	características	básicas	de	las	imágenes.
#
# Finalmente,	se	ha	dejado	en	evidencia	lo	importante	que	es	experimentar	con	distintas	arquitecturas	de	redes convolucionales	para obtener	resultados	satisfactorios	aún	contando	con	limitaciones	importantes	como	una cantidad	relativamente	pequeña	de	datos	y	poco poder	de	procesamiento.
